# %% [markdown]
# # LegislationAnalytics: Парсинг и анализ данных из системы обеспечения законодательной деятельности

# %% [markdown]
# Этот файл содержит код, реализующий этапы сбора и обработки данных, необходимых для анализа факторов, влияющих на скорость принятия законопроектов. Основное внимание уделено автоматизированному парсингу данных с сайта "Система обеспечения законодательной деятельности" и структурированию информации для дальнейшего анализа.

# %% [markdown]
# ### Парсинг страниц законопроектов

# %%
import requests
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
from itertools import chain
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Напишем функцию, которая забирает все ссылки на законопроекты с одной страницы результатов:

# %%
def get_all_links(link):
    """
    Return the list of all links from 
    one page of results (10 by default)
    """
    page = requests.get(link)
    soup = BeautifulSoup(page.text)

    divs = soup.find_all("div", class_ = "o_top")
    links = [d.find("a") for d in divs]
    links_clean = list(filter(lambda x : x is not None, links))
    hrefs = [a.get("href") for a in links_clean]
    
    return hrefs

# %% [markdown]
# Теперь можем подставлять вместо `i` в `page` любое число в цикле и получать списки со ссылками.

# %%
conv6 = []

for i in range(1, 717):
    li = f"https://sozd.duma.gov.ru/oz?b[Convocation][]=6&b[ClassOfTheObjectLawmakingId]=1&page={i}&#data_source_tab_b"
    res = get_all_links(li)
    conv6.extend(res)
    sleep(3)

# %%
conv7 = []
for i in range(1, 574):
    li = f"https://sozd.duma.gov.ru/oz?b[Convocation][]=7&b[ClassOfTheObjectLawmakingId]=1&page={i}&#data_source_tab_b"
    res = get_all_links(li)
    conv7.extend(res)
    sleep(3)

# %% [markdown]
# Сформируем список ссылок на страницы законопроектов, представляющий собой последовательность URL-адресов в полном формате. Это упростит последующий процесс парсинга информации с каждой страницы. Для сохранения промежуточных результатов и предотвращения потери данных экспортируем эти ссылки в файл, что обеспечит их доступность для повторного использования.

# %%
final_6 = ["https://sozd.duma.gov.ru" + li for li in conv6]
df_conv_6 = pd.DataFrame(final_6)
df_conv_6.to_csv("conv6.csv")

final_7 = ["https://sozd.duma.gov.ru" + li for li in conv7]
df_conv_7 = pd.DataFrame(final_7)
df_conv_7.to_csv("conv7.csv")

# %% [markdown]
# ### Извлечение данных со страниц законопроектов

# %% [markdown]
# После парсинга HTML-контента выполняется обработка и извлечение ключевой информации о законопроектах. Используется библиотека BeautifulSoup для поиска и структурирования данных.

# %% [markdown]
# Напишем функцию, которая забирает всю нужную нам информацию со страницы законопроекта:

# %%
def get_bill(link0, convocation):
    try:
        # Отправляем запрос на страницу
        page = requests.get(link0)
        soup = BeautifulSoup(page.text)

        # Парсинг основной таблицы
        table = soup.find("table")
        if table is None:
            raise ValueError("Таблица с данными не найдена на странице.")
        df = pd.read_html(str(table))[0].set_index(0).T

        # Извлечение номера законопроекта и ссылки
        title = soup.find("title").text.split()[0]
        df["Номер"] = title
        df["Ссылка"] = link0

        # Парсинг дат
        date_init = soup.find_all("div", class_="bh_etap_date")[0].find("span", class_="mob_not").text
        date_acept = soup.find_all("div", class_="bh_etap_date")[-1].find("span", class_="mob_not").text
        df["Дата внесения"] = date_init
        df["Дата принятия/не принятия"] = date_acept

        # Определение статуса законопроекта
        h_bar = soup.find("div", class_="bill_gorizontal_progress")
        if h_bar is None:
            raise ValueError("Полоса прогресса законопроекта не найдена.")
        divs = h_bar.find_all("div")
        classes = [d.get("class") for d in divs]
        classes_plain = list(chain.from_iterable(classes))
        greens_c = classes_plain.count("green")
        status = "принят" if greens_c == 8 else "не принят"
        df["Статус"] = status

        # Добавляем номер созыва
        df["Созыв"] = convocation

        return df

    except requests.exceptions.RequestException as e:
        print(f"Ошибка сети при обработке ссылки {link0}: {e}")
    except ValueError as e:
        print(f"Ошибка данных при обработке ссылки {link0}: {e}")
    except Exception as e:
        print(f"Неизвестная ошибка при обработке ссылки {link0}: {e}")

    return None

# %% [markdown]
# Напишем функцию, которая будет циклом парсить данные со страниц:

# %%
def parse_bills(links, convocation):
    parsed_bills = []
    for link in links:
        try:
            bill_data = get_bill(link, convocation=convocation)
            if bill_data is not None:  
                parsed_bills.append(bill_data)
        except Exception as e:
            print(f"Ошибка при обработке ссылки {link}: {e}")
    return parsed_bills

# %% [markdown]
# Запустим функцию для каждого созыва, объеденим датафреймы и выгрузим в `csv` файл.

# %%
all_bills = []

bills_6 = parse_bills(final_6, convocation=6)
# Out:
# Ошибка данных при обработке ссылки https://sozd.duma.gov.ru/bill/1098517-6: Таблица с данными не найдена на странице.
# Неизвестная ошибка при обработке ссылки https://sozd.duma.gov.ru/bill/481943-6: 'NoneType' object has no attribute 'text'

# %%
bills_6
# Out:
# [0 Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы Д.В.Ушаков   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  060.000.000 Труд и занятость населения              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1187320-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1187320-6    04.10.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                10.03.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы Д.В.Ушаков   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  060.000.000 Труд и занятость населения              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1187319-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1187319-6    04.10.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                10.03.2017  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы М.В.Емельянов, Д...   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1187318-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1187318-6    04.10.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                22.03.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по делам Содружес...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по международным ...
#
#  0                           Отрасль законодательства  \
#  1  200.000.000 Международные отношения. Междунаро...
#
#  0                   Тематический блок законопроектов  \
#  1  Ратификация международных договоров Российской...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по делам Содружес...
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0                    Вопрос ведения Пакет документов при внесении       Номер  \
#  1  Ведение Конституционного Суда РФ                           NaN  №1187317-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1187317-6    04.10.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                29.12.2016  принят      6  ,
#  0  Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы В.Н.Тетекин   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0                                 Профильный комитет     Предмет ведения  \
#  1  Комитет Государственной Думы по бюджету и налогам  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1187303-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1187303-6    04.10.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                12.10.2017  не принят      6  ,
#  0  Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы Д.Г.Новиков   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по информационной...
#
#  0                           Отрасль законодательства  \
#  1  120.040.020 Информационные системы, технологии...
#
#  0 Тематический блок законопроектов  \
#  1           Экономическая политика
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по информационной...      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1187187-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1187187-6    04.10.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                18.10.2017  не принят      6  ,
#  0  Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы Д.Г.Новиков   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по информационной...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по экономической ...
#
#  0                           Отрасль законодательства  \
#  1  120.040.020 Информационные системы, технологии...
#
#  0 Тематический блок законопроектов  \
#  1           Экономическая политика
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по информационной...      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1187178-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1187178-6    04.10.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                18.10.2017  не принят      6  ,
#  0   Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы И.Е.Костунов   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0                           Отрасль законодательства  \
#  1  020.060.000 Административные правонарушения и ...
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1186921-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1186921-6    04.10.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                07.07.2017  не принят      6  ,
#  0   Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы И.Е.Костунов   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0                           Отрасль законодательства  \
#  1  170.000.000 Уголовное право. Исполнение наказаний
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0              Вопрос ведения Пакет документов при внесении       Номер  \
#  1  Ведение Верховного Суда РФ                           NaN  №1186913-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1186913-6    04.10.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                07.07.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по международным ...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                           Отрасль законодательства  \
#  1  200.000.000 Международные отношения. Междунаро...
#
#  0                   Тематический блок законопроектов  \
#  1  Ратификация международных договоров Российской...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по международным ...
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1186681-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1186681-6    04.10.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                20.12.2016  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                           Отрасль законодательства  \
#  1  070.000.000 Социальное обеспечение и социально...
#
#  0 Тематический блок законопроектов  \
#  1              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1186679-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1186679-6    04.10.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                07.03.2017  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по экономической ...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по физической кул...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  090.000.000 Хозяйственная деятельность           Экономическая политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по экономической ...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1186370-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1186370-6    03.10.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                22.02.2017  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                    Ответственный комитет  \
#  1  Комитет Государственной Думы по обороне
#
#  0                             Комитеты-соисполнители Отрасль законодательства  \
#  1  Комитет Государственной Думы по федеративному ...      150.000.000 Оборона
#
#  0 Тематический блок законопроектов                       Профильный комитет  \
#  1           Оборона и безопасность  Комитет Государственной Думы по обороне
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1186354-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1186354-6    03.10.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                22.02.2017  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1           Президент Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по международным ...
#
#  0                           Отрасль законодательства  \
#  1  200.000.000 Международные отношения. Междунаро...
#
#  0                   Тематический блок законопроектов  \
#  1  Ратификация международных договоров Российской...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по международным ...
#
#  0 Заключение Правительства РФ на законопроект Пакет документов при внесении  \
#  1                                   требуется                           NaN
#
#  0       Номер                                   Ссылка Дата внесения  \
#  1  №1186208-6  https://sozd.duma.gov.ru/bill/1186208-6    03.10.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                31.10.2016  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1    Государственный Совет Республики Крым   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по федеративному ...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по природным ресу...
#
#  0            Отрасль законодательства  \
#  1  010.150.000 Местное самоуправление
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по федеративному ...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0                    Вопрос ведения Пакет документов при внесении       Номер  \
#  1  Ведение Конституционного Суда РФ                           NaN  №1184991-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1184991-6    30.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                18.01.2017  не принят      6  ,
#  0   Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы С.Б.Дорофеев   Федеральный закон
#
#  0                            Ответственный комитет  \
#  1  Комитет Государственной Думы по охране здоровья
#
#  0                           Отрасль законодательства  \
#  1  140.000.000 Здравоохранение. Физическая культу...
#
#  0 Тематический блок законопроектов  \
#  1              Социальная политика
#
#  0                               Профильный комитет     Предмет ведения  \
#  1  Комитет Государственной Думы по охране здоровья  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1184882-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1184882-6    29.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                26.05.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по региональной п...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по делам национал...
#
#  0                           Отрасль законодательства  \
#  1  070.000.000 Социальное обеспечение и социально...
#
#  0 Тематический блок законопроектов  \
#  1              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по региональной п...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0                    Вопрос ведения Пакет документов при внесении       Номер  \
#  1  Ведение Конституционного Суда РФ                           NaN  №1184180-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1184180-6    29.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                21.05.2018  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по бюджету и налогам      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1184172-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1184172-6    29.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                30.11.2016  принят      6  ,
#  0   Субъект права законодательной инициативы Форма законопроекта  \
#  1  Законодательное Собрание Санкт-Петербурга   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0                           Отрасль законодательства  \
#  1  170.000.000 Уголовное право. Исполнение наказаний
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по государственно...      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1183720-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1183720-6    28.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                12.09.2017  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы В.Ф.Рашкин, С.П....   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  060.000.000 Труд и занятость населения              Социальная политика
#
#  0                                 Профильный комитет     Предмет ведения  \
#  1  Комитет Государственной Думы по труду, социаль...  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1183613-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1183613-6    28.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                24.01.2018  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по информационной...
#
#  0                             Комитеты-соисполнители Отрасль законодательства  \
#  1  Комитет Государственной Думы по экономической ...      120.060.000 Реклама
#
#  0 Тематический блок законопроектов  \
#  1           Экономическая политика
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по экономической ...      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1183395-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1183395-6    28.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                05.12.2016  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы С.Ш.Мурзабаева; Ч...   Федеральный закон
#
#  0                        Отрасль законодательства  \
#  1  160.000.000 Безопасность и охрана правопорядка
#
#  0 Тематический блок законопроектов  \
#  1              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по вопросам семьи...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1183394-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1183394-6    28.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                20.12.2016  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы С.Ш.Мурзабаева; Ч...   Федеральный закон
#
#  0                        Отрасль законодательства  \
#  1  160.000.000 Безопасность и охрана правопорядка
#
#  0 Тематический блок законопроектов  \
#  1              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по вопросам семьи...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                   Требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1183390-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1183390-6    28.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                01.11.2016  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по бюджету и налогам      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1183284-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1183284-6    28.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                30.11.2016  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1           Президент Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по международным ...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по безопасности и...
#
#  0                           Отрасль законодательства  \
#  1  200.000.000 Международные отношения. Междунаро...
#
#  0                   Тематический блок законопроектов  \
#  1  Ратификация международных договоров Российской...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по международным ...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1183175-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1183175-6    28.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                22.11.2016  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                           Отрасль законодательства  \
#  1  070.000.000 Социальное обеспечение и социально...
#
#  0 Тематический блок законопроектов  \
#  1              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1182038-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1182038-6    26.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                29.12.2016  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Государственное Собрание - Курултай Республики...   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  060.000.000 Труд и занятость населения              Социальная политика
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по труду, социаль...      Ведение РФ
#
#  0 Пакет документов при внесении Новая редакция законопроекта       Номер  \
#  1                           NaN             22.04.2017 12:20  №1181957-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1181957-6    26.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                31.12.2017  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1           Президент Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0                           Отрасль законодательства  \
#  1  170.000.000 Уголовное право. Исполнение наказаний
#
#  0                   Тематический блок законопроектов  \
#  1  Ратификация международных договоров Российской...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                   Требуется      Ведение РФ
#
#  0              Вопрос ведения Пакет документов при внесении       Номер  \
#  1  Ведение Верховного Суда РФ                           NaN  №1181157-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1181157-6    23.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                22.11.2016  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                       Ответственный комитет  \
#  1  Комитет Государственной Думы по энергетике
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по жилищной полит...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  090.000.000 Хозяйственная деятельность           Экономическая политика
#
#  0                          Профильный комитет  \
#  1  Комитет Государственной Думы по энергетике
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1180827-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1180827-6    23.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                30.07.2017  принят      6  ,
#  0    Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы М.В.Емельянов   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по экономической ...
#
#  0                           Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по охране здоровья
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  090.000.000 Хозяйственная деятельность           Экономическая политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по экономической ...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1180507-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1180507-6    22.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                09.06.2017  не принят      6  ,
#  0  Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы С.А.Доронин   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по бюджету и налогам      080.000.000 Финансы
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                   Требуется      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1180424-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1180424-6    22.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                22.02.2017  не принят      6  ,
#  0  Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы С.А.Доронин   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по экологии и охр...
#
#  0                           Отрасль законодательства  \
#  1  110.000.000 Природные ресурсы и охрана окружаю...
#
#  0 Тематический блок законопроектов  \
#  1           Экономическая политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по экологии и охр...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                   Требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1180375-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1180375-6    22.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                22.03.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы И.Н.Игошин   Федеральный закон
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0              Вопрос ведения Пакет документов при внесении       Номер  \
#  1  Ведение Верховного Суда РФ                           NaN  №1179304-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1179304-6    21.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                24.01.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по финансовому рынку
#
#  0                             Комитеты-соисполнители Отрасль законодательства  \
#  1  Комитет Государственной Думы по бюджету и нало...      080.000.000 Финансы
#
#  0                   Тематический блок законопроектов  \
#  1  Ратификация международных договоров Российской...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по финансовому рынку
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1179027-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1179027-6    21.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                29.12.2016  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы М.П.Максакова-Иге...   Федеральный закон
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1178822-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1178822-6    20.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                01.11.2016  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по безопасности и...
#
#  0           Отрасль законодательства Тематический блок законопроектов  \
#  1  010.000.000 Конституционный строй           Оборона и безопасность
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по безопасности и...      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1177915-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1177915-6    20.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                29.12.2016  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по бюджету и налогам      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1177918-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1177918-6    20.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                30.11.2016  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                           Отрасль законодательства  \
#  1  070.000.000 Социальное обеспечение и социально...
#
#  0 Тематический блок законопроектов  \
#  1              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1177914-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1177914-6    20.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                22.11.2016  принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по безопасности и...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по природным ресу...
#
#  0           Отрасль законодательства Тематический блок законопроектов  \
#  1  160.040.050 Пожарная безопасность           Оборона и безопасность
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по безопасности и...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1177587-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1177587-6    19.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                29.05.2017  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Члены Совета Федерации В.И.Матвиенко, Г.Н.Каре...   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по природным ресу...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по региональной п...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  090.000.000 Хозяйственная деятельность           Экономическая политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по земельным отно...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1177357-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1177357-6    19.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                29.12.2016  принят      6  ,
#  0     Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы С.Ш.Мурзабаева   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по вопросам семьи...        040.000.000 Семья
#
#  0 Тематический блок законопроектов  \
#  1              Социальная политика
#
#  0                                 Профильный комитет     Предмет ведения  \
#  1  Комитет Государственной Думы по вопросам семьи...  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1177252-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1177252-6    19.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                20.04.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1  Законодательное Собрание Пермского края   Федеральный закон
#
#  0     Отрасль законодательства Тематический блок законопроектов  \
#  1  140.010.000 Здравоохранение              Социальная политика
#
#  0                               Профильный комитет  \
#  1  Комитет Государственной Думы по охране здоровья
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                   Требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1176823-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1176823-6    19.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                20.10.2016  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутат Государственной Думы О.Н.Смолин   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по жилищной полит...
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по жилищной полит...
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                   Требуется      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1175399-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1175399-6    15.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                20.04.2017  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы А.Н.Диденко, М.В...   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по природным ресу...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  090.000.000 Хозяйственная деятельность           Экономическая политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по земельным отно...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1175109-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1175109-6    15.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                12.04.2018  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы С.М.Миронов, О.Л...   Федеральный закон
#
#  0                           Отрасль законодательства  \
#  1  170.000.000 Уголовное право. Исполнение наказаний
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1175106-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1175106-6    15.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                29.11.2016  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы О.Л.Михеев, С.А....   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0                           Отрасль законодательства  \
#  1  020.060.000 Административные правонарушения и ...
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1175091-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1175091-6    15.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                23.03.2018  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы Я.Е.Нилов, М.В.Д...   Федеральный закон
#
#  0 Отрасль законодательства Тематический блок законопроектов  \
#  1        040.000.000 Семья              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по вопросам семьи...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                   Требуется  Совместное ведение
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1174985-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1174985-6    15.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                18.10.2016  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы В.Ф.Рашкин, С.П....   Федеральный закон
#
#  0 Отрасль законодательства                   Тематический блок законопроектов  \
#  1      080.000.000 Финансы  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0 Заключение Правительства РФ на законопроект Пакет документов при внесении  \
#  1                                   Требуется                           NaN
#
#  0       Номер                                   Ссылка Дата внесения  \
#  1  №1174409-6  https://sozd.duma.gov.ru/bill/1174409-6    14.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                18.10.2016  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы А.Б.Курдюмов, А....   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по финансовому рынку      080.000.000 Финансы
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по финансовому рынку
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                   Требуется      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1174086-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1174086-6    14.09.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                23.03.2018  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по экономической ...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по делам национал...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  090.000.000 Хозяйственная деятельность           Экономическая политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по экономической ...
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0 Пакет документов при внесении       Номер  \
#  1                           NaN  №1173483-6
#
#  0                                   Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/1173483-6    13.09.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
# ...
#  1  https://sozd.duma.gov.ru/bill/999273-6    17.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                14.03.2016  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы С.М.Миронов, Г.П...   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по жилищной полит...       050.000.000 Жилище
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по жилищной полит...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №999213-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/999213-6    17.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                22.05.2018  не принят      6  ,
#  0     Субъект права законодательной инициативы Форма законопроекта  \
#  1  Законодательное Собрание Пензенской области   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по финансовому рынку      080.000.000 Финансы
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по финансовому рынку
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №998974-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/998974-6    17.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                12.04.2016  не принят      6  ,
#  0     Субъект права законодательной инициативы Форма законопроекта  \
#  1  Законодательное Собрание Пензенской области   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по государственно...
#
#  0                        Отрасль законодательства  \
#  1  020.000.000 Основы государственного управления
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по конституционно...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №998965-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/998965-6    17.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                12.04.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                       Ответственный комитет  \
#  1  Комитет Государственной Думы по транспорту
#
#  0 Тематический блок законопроектов  \
#  1           Экономическая политика
#
#  0                          Профильный комитет  \
#  1  Комитет Государственной Думы по транспорту
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №998780-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/998780-6    16.02.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                04.07.2016  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы А.Н.Шерин, В.В.С...   Федеральный закон
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по вопросам семьи...
#
#  0 Заключение Правительства РФ на законопроект Пакет документов при внесении  \
#  1                                   Требуется                           NaN
#
#  0      Номер                                  Ссылка Дата внесения  \
#  1  №998765-6  https://sozd.duma.gov.ru/bill/998765-6    16.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                17.03.2016  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы А.Г.Аксаков, А.В...   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по финансовому рынку      080.000.000 Финансы
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по финансовому рынку
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №998726-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/998726-6    16.02.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                28.03.2017  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы А.А.Озеров, О.Л....   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по конституционно...
#
#  0                             Комитеты-соисполнители  \
#  1  Комитет Государственной Думы по информационной...
#
#  0                           Отрасль законодательства  \
#  1  020.060.000 Административные правонарушения и ...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по конституционно...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №998445-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/998445-6    16.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                08.06.2016  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по бюджету и налогам      080.000.000 Финансы
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по бюджету и налогам      Ведение РФ
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №997996-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/997996-6    16.02.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                30.03.2016  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы С.Б.Дорофеев, О....   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0                Отрасль законодательства Тематический блок законопроектов  \
#  1  060.000.000 Труд и занятость населения              Социальная политика
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по труду, социаль...
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №997875-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/997875-6    16.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                18.01.2017  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1       Правительство Российской Федерации   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по бюджету и налогам
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по бюджету и налогам      Ведение РФ
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №997654-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/997654-6    16.02.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                29.02.2016  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы Н.Н.Гончар, М.А....   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по финансовому рынку      080.000.000 Финансы
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по финансовому рынку
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №997129-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/997129-6    15.02.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                30.07.2018  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы Н.Н.Гончар, М.А....   Федеральный закон
#
#  0                              Ответственный комитет Отрасль законодательства  \
#  1  Комитет Государственной Думы по финансовому рынку      080.000.000 Финансы
#
#  0                   Тематический блок законопроектов  \
#  1  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по финансовому рынку
#
#  0 Заключение Правительства РФ на законопроект Предмет ведения  \
#  1                                Не требуется      Ведение РФ
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №997126-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/997126-6    15.02.2016
#
#  0 Дата принятия/не принятия  Статус  Созыв
#  1                04.07.2016  принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы В.Ф.Рашкин, В.Р....   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по конституционно...
#
#  0                        Отрасль законодательства  \
#  1  020.000.000 Основы государственного управления
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по конституционно...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                Не требуется  Совместное ведение
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №996924-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/996924-6    15.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                07.06.2016  не принят      6  ,
#  0           Субъект права законодательной инициативы  \
#  1  Депутаты Государственной Думы С.М.Миронов, Н.В...
#
#  0                Форма законопроекта  \
#  1  Федеральный конституционный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по конституционно...
#
#  0                        Отрасль законодательства  \
#  1  020.000.000 Основы государственного управления
#
#  0                                 Профильный комитет Предмет ведения  \
#  1  Комитет Государственной Думы по конституционно...      Ведение РФ
#
#  0 Наличие актуального Заключения Правового Управления      Номер  \
#  1                                                нет   №996787-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/996787-6    15.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                18.05.2016  не принят      6  ,
#  0           Субъект права законодательной инициативы Форма законопроекта  \
#  1  Депутаты Государственной Думы И.И.Никитчук, Н....   Федеральный закон
#
#  0 Отрасль законодательства                   Тематический блок законопроектов  \
#  1      080.000.000 Финансы  Бюджетное, налоговое, финансовое законодательство
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по финансовому рынку
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №996741-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/996741-6    15.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                21.03.2016  не принят      6  ,
#  0    Субъект права законодательной инициативы Форма законопроекта  \
#  1  Архангельское областное Собрание депутатов   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по делам обществе...
#
#  0           Отрасль законодательства  \
#  1  010.000.000 Конституционный строй
#
#  0                   Тематический блок законопроектов  \
#  1  Государственное строительство и конституционны...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по делам обществе...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                   требуется  Совместное ведение
#
#  0 Пакет документов при внесении      Номер  \
#  1                           NaN  №996615-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/996615-6    15.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                09.12.2016  не принят      6  ,
#  0 Субъект права законодательной инициативы Форма законопроекта  \
#  1               Сахалинская областная Дума   Федеральный закон
#
#  0                              Ответственный комитет  \
#  1  Комитет Государственной Думы по региональной п...
#
#  0                           Отрасль законодательства  \
#  1  070.000.000 Социальное обеспечение и социально...
#
#  0                                 Профильный комитет  \
#  1  Комитет Государственной Думы по региональной п...
#
#  0 Заключение Правительства РФ на законопроект     Предмет ведения  \
#  1                                   Требуется  Совместное ведение
#
#  0                    Вопрос ведения Пакет документов при внесении      Номер  \
#  1  Ведение Конституционного Суда РФ                           NaN  №996502-6
#
#  0                                  Ссылка Дата внесения  \
#  1  https://sozd.duma.gov.ru/bill/996502-6    15.02.2016
#
#  0 Дата принятия/не принятия     Статус  Созыв
#  1                22.11.2017  не принят      6  ,
#  ...]

# %%
bills_7 = parse_bills(final_7, convocation=7)

# %%
all_bills = []

bills_6 = parse_bills(final_6, convocation=6)
bills_7 = parse_bills(final_7, convocation=7)
all_bills = pd.concat(bills_6 + bills_7, ignore_index=True)
all_bills.to_csv("all_bills_6th_and_7th_convocation.csv", index=False)

# %%
all_bills = pd.concat(bills_6 + bills_7, ignore_index=True)
all_bills.to_csv("all_bills_6th_and_7th_convocation.csv", index=False)

# %%
# на входе: ссылка на один з/п
# на выходе: датафрейм + CSV для одного з/п

def get_bill(link0):
    page = requests.get(link0)
    soup = BeautifulSoup(page.text)
    df = pd.read_html(str(soup.find("table")))[0].set_index(0).T
    title = soup.find("title").text.split()[0]
    df["Номер"] = title
    df["Ссылка"] = link0
    
    date_introd = soup.find_all("div", 
                                class_ = "bh_etap_date")[0].find("span", 
                                                                 class_ = "mob_not").text
    date_fin = soup.find_all("div", 
      class_ = "bh_etap_date")[-1].find("span", class_ = "mob_not").text
    df["Дата внесения"] = date_introd
    df["Дата принятия/не принятия"] = date_fin
    
    h_bar = soup.find("div", class_ = "bill_gorizontal_progress")
    divs = h_bar.find_all("div")
    classes = [d.get("class") for d in divs]
    classes_plain = list(chain.from_iterable(classes))
    greens_c = classes_plain.count("green")
    
    if greens_c == 8:
        status = "принят"
    else:
        status = "не принят"
    df["Статус"] = status
    df.to_csv(title + ".csv")
    return df

# %%
dat_links = pd.read_excel("conv6_part01.xlsx")
to_iterate = dat_links[0].values

for i in to_iterate:
    get_bill(i)
    sleep(2)
    print(i) # на случай, если остановится/сломается, видеть ссылку
